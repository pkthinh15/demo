# %%
from utils import dct2,idct2,s
import cv2

# %%
im = cv2.imread("input/lenna.png")
gray = cv2.cvtColor(im,cv2.COLOR_BGR2GRAY)
s(gray)

# %% [markdown]
# # Energy Compaction Illustration

# %%
imF = dct2(gray)
print(imF)
s(imF)
# Out:
# [[ 6.35128633e+04 -5.21850422e+03 -1.21721267e+03 ... -5.90529034e-01
#   -7.11517271e+00 -1.39862141e+01]
#  [ 3.55013767e+03  3.89919813e+03 -3.24871553e+03 ...  5.61332519e+00
#    9.11377111e+00  1.56048152e+01]
#  [-1.04262077e+02  1.55847238e+03 -2.99258001e+03 ... -6.13698478e-01
#   -7.58876263e+00 -1.97663414e-01]
#  ...
#  [-1.23680602e-01 -3.12160748e+00 -2.89138527e+00 ... -1.15678055e+00
#    3.25362380e+00  1.55317266e+00]
#  [ 3.53860382e+00 -2.20253249e+00  3.37070569e+00 ... -9.50482370e-01
#   -4.19621127e-01  3.37591028e+00]
#  [-1.69605704e+00  7.57253867e-01 -1.92901820e+00 ...  1.74143409e+00
#    3.86244884e+00  5.97908778e-02]]

# %%
invert_im = idct2(imF)
s(invert_im)
